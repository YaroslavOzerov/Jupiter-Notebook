# %% [markdown]
# <a href="https://colab.research.google.com/github/YaroslavOzerov/CineLingo/blob/main/Untitled33.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import ai
response = ai.generate_text(input())
print(response)
# Out:
# как  лучше всего изучать пользу кодинга нужно ли сначала поставить задачу а потом изучать существующие инструмнты такие как бибилиотеки
# Это очень правильный вопрос, и ваш инстинкт насчет "сначала задача, потом инструменты" абсолютно верен для большинства людей! Давайте разберем его по пунктам.
#
# ### Как лучше всего изучать пользу кодинга?
#
# Изучать пользу кодинга лучше всего не в теории, а на **практических примерах и через личный опыт**.
#
# 1.  **Смотрите на результаты:**
#     *   **Оглянитесь вокруг:** Практически все, чем вы пользуетесь ежедневно – от смартфона и умных часов до веб-сайтов, приложений, социальных сетей, банковских систем, навигации, онлайн-игр – создано с помощью кода. Попробуйте представить мир без этих вещей.
# ...

# %% [markdown]
# Эта функция показывает что мы имеем
